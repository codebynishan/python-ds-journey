# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/forbes.csv")
df
# Out:
#       rank                personName   age  finalWorth  year  month  \
# 0        1                 Elon Musk  50.0    219000.0  2022      4
# 1        2                Jeff Bezos  58.0    171000.0  2022      4
# 2        3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3        4                Bill Gates  66.0    129000.0  2022      4
# 4        5            Warren Buffett  91.0    118000.0  2022      4
# ...    ...                       ...   ...         ...   ...    ...
# 2663  2578             Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578                Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578         Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578      Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578   Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#                    category                   source        country  \
# 0                Automotive            Tesla, SpaceX  United States
# ...

# %%
df.head()
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0    219000.0  2022      4
# 1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2     3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3     4                Bill Gates  66.0    129000.0  2022      4
# 4     5            Warren Buffett  91.0    118000.0  2022      4
#
#                 category              source        country       state  ...  \
# 0             Automotive       Tesla, SpaceX  United States       Texas  ...
# 1             Technology              Amazon  United States  Washington  ...
# 2       Fashion & Retail                LVMH         France         NaN  ...
# 3             Technology           Microsoft  United States  Washington  ...
# 4  Finance & Investments  Berkshire Hathaway  United States    Nebraska  ...
#
#                        organization selfMade gender   birthDate  \
# ...

# %%
df.describe()
# Out:
#               rank          age     finalWorth    year   month  \
# count  2668.000000  2582.000000    2668.000000  2668.0  2668.0
# mean   1302.919040    64.210689    4762.350075  2022.0     4.0
# std     747.807782    13.401258   10540.482258     0.0     0.0
# min       1.000000    19.000000    1000.000000  2022.0     4.0
# 25%     665.000000    55.000000    1500.000000  2022.0     4.0
# 50%    1292.000000    64.000000    2400.000000  2022.0     4.0
# 75%    1929.000000    74.000000    4300.000000  2022.0     4.0
# max    2578.000000   100.000000  219000.000000  2022.0     4.0
#
#        philanthropyScore  numberOfSiblings
# count         396.000000        127.000000
# mean            1.856061          2.732283
# std             0.971486          1.891706
# min             1.000000          1.000000
# 25%             1.000000          2.000000
# 50%             2.000000          2.000000
# 75%             2.000000          3.000000
# max             5.000000         14.000000

# %%
df.columns
# Out:
# Index(['rank', 'personName', 'age', 'finalWorth', 'year', 'month', 'category',
#        'source', 'country', 'state', 'city', 'countryOfCitizenship',
#        'organization', 'selfMade', 'gender', 'birthDate', 'title',
#        'philanthropyScore', 'residenceMsa', 'numberOfSiblings', 'bio',
#        'about'],
#       dtype='object')

# %%
newdf=df.loc[:,["rank","personName","age","finalWorth","year","category","country","gender"]]

newdf
# Out:
#       rank                personName   age  finalWorth  year  \
# 0        1                 Elon Musk  50.0    219000.0  2022
# 1        2                Jeff Bezos  58.0    171000.0  2022
# 2        3  Bernard Arnault & family  73.0    158000.0  2022
# 3        4                Bill Gates  66.0    129000.0  2022
# 4        5            Warren Buffett  91.0    118000.0  2022
# ...    ...                       ...   ...         ...   ...
# 2663  2578             Zhang Yuqiang  66.0      1000.0  2022
# 2664  2578                Zhou Ruxin  59.0      1000.0  2022
# 2665  2578         Wen Zhou & family  57.0      1000.0  2022
# 2666  2578      Zhou Yifeng & family  43.0      1000.0  2022
# 2667  2578   Zhuang Kuilong & family  59.0      1000.0  2022
#
#                    category        country gender
# 0                Automotive  United States      M
# 1                Technology  United States      M
# 2          Fashion & Retail         France      M
# ...

# %%
newdf.set_index("rank")
# Out:
#                     personName   age  finalWorth  year               category  \
# rank
# 1                    Elon Musk  50.0    219000.0  2022             Automotive
# 2                   Jeff Bezos  58.0    171000.0  2022             Technology
# 3     Bernard Arnault & family  73.0    158000.0  2022       Fashion & Retail
# 4                   Bill Gates  66.0    129000.0  2022             Technology
# 5               Warren Buffett  91.0    118000.0  2022  Finance & Investments
# ...                        ...   ...         ...   ...                    ...
# 2578             Zhang Yuqiang  66.0      1000.0  2022          Manufacturing
# 2578                Zhou Ruxin  59.0      1000.0  2022             Technology
# 2578         Wen Zhou & family  57.0      1000.0  2022          Manufacturing
# 2578      Zhou Yifeng & family  43.0      1000.0  2022                 Energy
# 2578   Zhuang Kuilong & family  59.0      1000.0  2022          Manufacturing
#
# ...

# %%
newdf.isnull().sum()
# Out:
# rank           0
# personName     0
# age           86
# finalWorth     0
# year           0
# category       0
# country       13
# gender        16
# dtype: int64

# %%
newdf.dropna(inplace=True)

# %%
newdf.shape
# Out:
# (2568, 8)

# %%
newdf["gender"].value_counts()
# Out:
# gender
# M    2282
# F     286
# Name: count, dtype: int64

# %%
newdf["gender"].value_counts(normalize=True)
# Out:
# gender
# M    0.888629
# F    0.111371
# Name: proportion, dtype: float64

# %%
newdf[newdf["country"]=="China"].gender.value_counts(normalize=True)
# Out:
# gender
# M    0.913919
# F    0.086081
# Name: proportion, dtype: float64

# %%
newdf[newdf["country"]=="United States"].gender.value_counts(normalize=True)
# Out:
# gender
# M    0.881402
# F    0.118598
# Name: proportion, dtype: float64

# %%
newdf[newdf["country"]=="Nepal"].gender.value_counts(normalize=True)
# Out:
# gender
# M    1.0
# Name: proportion, dtype: float64

# %%
newdf["personName"]
# Out:
# 0                      Elon Musk
# 1                     Jeff Bezos
# 2       Bernard Arnault & family
# 3                     Bill Gates
# 4                 Warren Buffett
#                   ...
# 2663               Zhang Yuqiang
# 2664                  Zhou Ruxin
# 2665           Wen Zhou & family
# 2666        Zhou Yifeng & family
# 2667     Zhuang Kuilong & family
# Name: personName, Length: 2568, dtype: object

# %%
newdf[newdf["country"]=="Nepal"][["personName","finalWorth"]]
# Out:
#            personName  finalWorth
# 1948  Binod Chaudhary      1500.0

# %%
newdf[newdf["country"]=="India"].gender.value_counts(normalize=True)
# Out:
# gender
# M    0.928571
# F    0.071429
# Name: proportion, dtype: float64

# %%
newdf["country"].unique()
# Out:
# array(['United States', 'France', 'India', 'Mexico', 'China', 'Singapore',
#        'Spain', 'Canada', 'Germany', 'Switzerland', 'Belgium',
#        'Hong Kong', 'United Kingdom', 'Australia', 'Austria', 'Italy',
#        'Japan', 'Bahamas', 'Indonesia', 'Chile', 'Russia', 'Sweden',
#        'Czechia', 'Monaco', 'United Arab Emirates', 'Nigeria', 'Denmark',
#        'Thailand', 'Malaysia', 'Brazil', 'Colombia', 'New Zealand',
#        'South Korea', 'South Africa', 'Philippines', 'Egypt', 'Taiwan',
#        'Israel', 'Vietnam', 'Poland', 'Norway', 'Cayman Islands',
#        'Netherlands', 'Eswatini (Swaziland)', 'Peru', 'Algeria',
#        'Kazakhstan', 'Georgia', 'Portugal', 'British Virgin Islands',
#        'Turkey', 'Finland', 'Ukraine', 'Ireland', 'Bermuda', 'Lebanon',
#        'Argentina', 'Cambodia', 'Oman', 'Guernsey', 'Liechtenstein',
#        'Turks and Caicos Islands', 'Qatar', 'Morocco', 'Uruguay',
#        'Slovakia', 'Romania', 'Nepal', 'Tanzania', 'Bahrain', 'Greece',
# ...

# %%
gender=newdf.groupby(["gender"])

# %%
gender["age"].mean()
# Out:
# gender
# F    62.937063
# M    64.409290
# Name: age, dtype: float64

# %%
import seaborn as sns

# %%
sns.barplot(y=newdf["personName"][:11],x=newdf["finalWorth"][:11])
# Out:
# <Axes: xlabel='finalWorth', ylabel='personName'>

# %%
len(newdf["country"].unique())
# Out:
# 73

# %%
country = newdf.groupby("country")

# %%
print(country)

# %%
df_country =pd.DataFrame(newdf["country"].value_counts().reset_index())

df_country
# Out:
#            country  count
# 0    United States    742
# 1            China    546
# 2            India    154
# 3          Germany     94
# 4   United Kingdom     81
# ..             ...    ...
# 68        Portugal      1
# 69         Georgia      1
# 70         Algeria      1
# 71        Colombia      1
# 72         Andorra      1
#
# [73 rows x 2 columns]

# %%
df_country.columns=["country","number"]

df_country
# Out:
#            country  number
# 0    United States     742
# 1            China     546
# 2            India     154
# 3          Germany      94
# 4   United Kingdom      81
# ..             ...     ...
# 68        Portugal       1
# 69         Georgia       1
# 70         Algeria       1
# 71        Colombia       1
# 72         Andorra       1
#
# [73 rows x 2 columns]

# %%
df_country =df_country.sort_values(by="number",ascending=False)

# %%
sns.barplot(y=df_country["country"][:11],x=df_country["number"][:11])
# Out:
# <Axes: xlabel='number', ylabel='country'>

# %%
df_india =newdf[newdf["country"]=="India"]

# %%
df_india["personName"].count()
# Out:
# np.int64(154)

# %%
df_india.head()
# Out:
#     rank             personName   age  finalWorth  year          category  \
# 9     10          Mukesh Ambani  64.0     90700.0  2022       Diversified
# 10    11  Gautam Adani & family  59.0     90000.0  2022       Diversified
# 46    47             Shiv Nadar  76.0     28700.0  2022        Technology
# 56    56       Cyrus Poonawalla  80.0     24300.0  2022        Healthcare
# 80    81     Radhakishan Damani  67.0     20000.0  2022  Fashion & Retail
#
#    country gender
# 9    India      M
# 10   India      M
# 46   India      M
# 56   India      M
# 80   India      M

# %%
sns.barplot(x=df_india["finalWorth"][:11],y=df_india["personName"][:11])
# Out:
# <Axes: xlabel='finalWorth', ylabel='personName'>

# %%
newdf["category"].unique()
# Out:
# array(['Automotive', 'Technology', 'Fashion & Retail',
#        'Finance & Investments', 'Diversified', 'Media & Entertainment',
#        'Telecom', 'Food & Beverage', 'Logistics', 'Real Estate',
#        'Metals & Mining', 'Manufacturing', 'Gambling & Casinos',
#        'Healthcare', 'Service', 'Energy', 'Construction & Engineering',
#        'Sports'], dtype=object)

# %%
df_category =newdf.groupby("category").size()

# %%
df_category.head()
# Out:
# category
# Automotive                     66
# Construction & Engineering     45
# Diversified                   174
# Energy                         93
# Fashion & Retail              238
# dtype: int64

# %%
df_category=df_category.to_frame()

# %%
df_category.head()
# Out:
#                               0
# category
# Automotive                   66
# Construction & Engineering   45
# Diversified                 174
# Energy                       93
# Fashion & Retail            238

# %%
df_category=df_category.rename(columns={0:"count", 1:"category"})

# %%
df_category
# Out:
#                             count
# category
# Automotive                     66
# Construction & Engineering     45
# Diversified                   174
# Energy                         93
# Fashion & Retail              238
# Finance & Investments         381
# Food & Beverage               193
# Gambling & Casinos             23
# Healthcare                    209
# Logistics                      32
# Manufacturing                 319
# Media & Entertainment          95
# Metals & Mining                65
# Real Estate                   187
# Service                        52
# Sports                         27
# Technology                    332
# Telecom                        37

# %%
df_category =df_category.sort_values(by="count",ascending=False)

# %%
sns.barplot(data=df_category.head(11), x="count", y="category", palette="bright")
# Out:
# /var/folders/mq/8k37xryj0_n2cz69zl90f1gm0000gn/T/ipykernel_2445/100635467.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_category.head(11), x="count", y="category", palette="bright")
# <Axes: xlabel='count', ylabel='category'>

# %%
sns.histplot(newdf["age"])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df_age =newdf.sort_values(by="age")

# %%
df_age
# Out:
#       rank                   personName    age  finalWorth  year  \
# 2190  2190           Alexandra Andresen   25.0      1300.0  2022
# 2062  1929                  Wang Zelong   25.0      1500.0  2022
# 1975  1929             Pedro Franceschi   25.0      1500.0  2022
# 1961  1929            Henrique Dubugras   26.0      1500.0  2022
# 2191  2190           Katharina Andresen   26.0      1300.0  2022
# ...    ...                          ...    ...         ...   ...
# 1939  1929  Ana Maria Brescia Cafferata   97.0      1500.0  2022
# 162    163                  Robert Kuok   98.0     11700.0  2022
# 1377  1341                David Murdock   98.0      2300.0  2022
# 1273  1238               Charles Munger   98.0      2500.0  2022
# 1681  1645                George Joseph  100.0      1800.0  2022
#
#                    category        country gender
# 2190            Diversified         Norway      F
# 2062        Metals & Mining          China      M
# ...

# %%
df_age =df_age.sort_values(by="age",ascending=True)

# %%
sns.barplot(y=df_age["personName"][:11],x= df_age["age"][:11])
# Out:
# <Axes: xlabel='age', ylabel='personName'>
